# %% [markdown]
# # Lab 5 - Clasificacion de imagenes: piedra, papel o tijeras.
#
# El objetivo de este laboratorio es entrenar un clasificador de imagenes para el siguiente dataset:
#
# https://public.roboflow.com/classification/rock-paper-scissors/

# %% [markdown]
# ## Preparación del entorno.
#
# Si no estamos parados en el repo, clonar y cd al repo. Esto nos permite usar el mismo notebook tanto local como en Google Colab.

# %%
import os

REPO_NAME = "lab5"
if REPO_NAME not in os.getcwd():
  if not os.path.exists(REPO_NAME):
    # !git clone https://github.com/FCEIA-AAII/{REPO_NAME}.git
  os.chdir(REPO_NAME)
# Out:
# Cloning into 'lab5'...
# remote: Enumerating objects: 2933, done.
# remote: Counting objects: 100% (2933/2933), done.
# remote: Compressing objects: 100% (2932/2932), done.
# remote: Total 2933 (delta 0), reused 2933 (delta 0), pack-reused 0
# Receiving objects: 100% (2933/2933), 15.02 MiB | 21.42 MiB/s, done.

# %% [markdown]
# Importar librerías

# %%
import numpy as np
from pathlib import Path
import tensorflow as tf
from keras.layers import Input, RandomFlip, RandomContrast, BatchNormalization, RandomTranslation, Flatten, Dropout
from keras.layers import Dense, Conv2D, Activation, MaxPooling2D, GlobalMaxPooling2D, Rescaling
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Establecer GPU por defecto en caso de estar disponible.

# %%
# Configurar para que TensorFlow utilice la GPU por defecto
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Configurar para que TensorFlow asigne memoria dinámicamente
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        # Especificar la GPU por defecto
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Manejar error
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# Cargar dataset:

# %%
# Directorio de los datos
DATA_DIRECTORY = Path("rock-paper-scissors/dataset")
# Tamaño del lote (batch size)
BATCH_SIZE = 64
# Tamaño de las imágenes
IMAGE_HEIGHT = 64
IMAGE_WIDTH = 64

# Carga los datos de entrenamiento y validación
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIRECTORY,
    validation_split=0.2,
    subset="training",
    label_mode="categorical",
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIRECTORY,
    validation_split=0.2,
    subset="validation",
    label_mode="categorical",
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE)
# Out:
# Found 2892 files belonging to 3 classes.
# Using 2314 files for training.
# Found 2892 files belonging to 3 classes.
# Using 578 files for validation.

# %% [markdown]
# Inspeccionar las clases:

# %%
# Obtiene los nombres de las clases
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['paper', 'rock', 'scissors']

# %% [markdown]
# Visualizar los datos:

# %%
# Muestra algunas imágenes de ejemplo
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    class_idx = list(labels[i]).index(1)
    plt.title(class_names[class_idx])
    plt.axis("off")

# %% [markdown]
# Definir la arquitectura de la red:

# %%
# Función para construir el modelo
def build_model(input_shape, output_labels):
    i = Input(input_shape, dtype=tf.float32)

    x = Rescaling(1./255)(i)
    x = RandomFlip("horizontal")(x)
    x = RandomFlip("vertical")(x)
    x = RandomTranslation(0.1, 0.1, fill_mode="reflect")(x)
    x = RandomContrast(0.2)(x)

    x = Conv2D(8, (3, 3))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(16, (3, 3))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(32, (3, 3))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling2D((2, 2))(x)

    x = GlobalMaxPooling2D()(x)
    x = Flatten()(x)
    x = Dropout(0.3)(x)
    x = Dense(output_labels)(x)
    x = Activation("softmax")(x)
    return tf.keras.Model(inputs=[i], outputs=[x])

# %% [markdown]
# Construir el modelo:

# %%
print("Building model")
model = build_model((IMAGE_HEIGHT, IMAGE_WIDTH, 3), num_classes)

model.compile(
    optimizer='adam',
    loss="categorical_crossentropy",
    metrics=['accuracy'])
# Out:
# Building model

# %% [markdown]
# Resumen del modelo:

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  rescaling (Rescaling)       (None, 64, 64, 3)         0
#
#  random_flip (RandomFlip)    (None, 64, 64, 3)         0
#
#  random_flip_1 (RandomFlip)  (None, 64, 64, 3)         0
#
#  random_translation (Random  (None, 64, 64, 3)         0
#  Translation)
#
#  random_contrast (RandomCon  (None, 64, 64, 3)         0
#  trast)
#
#  conv2d (Conv2D)             (None, 62, 62, 8)         224
#
#  batch_normalization (Batch  (None, 62, 62, 8)         32
#  Normalization)
#
#  activation (Activation)     (None, 62, 62, 8)         0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 16)        1168
#
#  batch_normalization_1 (Bat  (None, 60, 60, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 16)        0
#
#  max_pooling2d (MaxPooling2  (None, 30, 30, 16)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        4640
#
#  batch_normalization_2 (Bat  (None, 28, 28, 32)        128
#  chNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        18496
#
#  batch_normalization_3 (Bat  (None, 12, 12, 64)        256
#  chNormalization)
#
#  activation_3 (Activation)   (None, 12, 12, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  global_max_pooling2d (Glob  (None, 64)                0
#  alMaxPooling2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 3)                 195
#
#  activation_4 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 25203 (98.45 KB)
# Trainable params: 24963 (97.51 KB)
# Non-trainable params: 240 (960.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Entrenar el modelo:

# %%
# Número de épocas de entrenamiento
EPOCHS = 30
# Entrena el modelo
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE
)
# Out:
# Epoch 1/30
# 37/37 [==============================] - 2s 37ms/step - loss: 0.2432 - accuracy: 0.9149 - val_loss: 0.2029 - val_accuracy: 0.9689
# Epoch 2/30
# 37/37 [==============================] - 1s 31ms/step - loss: 0.2099 - accuracy: 0.9248 - val_loss: 0.3523 - val_accuracy: 0.8443
# Epoch 3/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.1741 - accuracy: 0.9339 - val_loss: 0.2882 - val_accuracy: 0.8754
# Epoch 4/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.1695 - accuracy: 0.9404 - val_loss: 0.8829 - val_accuracy: 0.5900
# Epoch 5/30
# 37/37 [==============================] - 2s 39ms/step - loss: 0.1671 - accuracy: 0.9412 - val_loss: 0.3771 - val_accuracy: 0.8080
# Epoch 6/30
# 37/37 [==============================] - 2s 44ms/step - loss: 0.1632 - accuracy: 0.9399 - val_loss: 0.4209 - val_accuracy: 0.7699
# Epoch 7/30
# 37/37 [==============================] - 1s 33ms/step - loss: 0.1274 - accuracy: 0.9589 - val_loss: 0.3845 - val_accuracy: 0.8270
# Epoch 8/30
# 37/37 [==============================] - 1s 31ms/step - loss: 0.1016 - accuracy: 0.9659 - val_loss: 0.2044 - val_accuracy: 0.8858
# Epoch 9/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.0987 - accuracy: 0.9659 - val_loss: 0.2444 - val_accuracy: 0.8806
# Epoch 10/30
# 37/37 [==============================] - 1s 33ms/step - loss: 0.1196 - accuracy: 0.9551 - val_loss: 0.4429 - val_accuracy: 0.7872
# Epoch 11/30
# 37/37 [==============================] - 1s 30ms/step - loss: 0.1166 - accuracy: 0.9568 - val_loss: 0.1383 - val_accuracy: 0.9412
# Epoch 12/30
# 37/37 [==============================] - 2s 41ms/step - loss: 0.1195 - accuracy: 0.9564 - val_loss: 0.0459 - val_accuracy: 0.9879
# Epoch 13/30
# 37/37 [==============================] - 2s 44ms/step - loss: 0.0991 - accuracy: 0.9663 - val_loss: 0.0238 - val_accuracy: 0.9965
# Epoch 14/30
# 37/37 [==============================] - 1s 33ms/step - loss: 0.0817 - accuracy: 0.9732 - val_loss: 0.0527 - val_accuracy: 0.9862
# Epoch 15/30
# 37/37 [==============================] - 2s 62ms/step - loss: 0.0779 - accuracy: 0.9741 - val_loss: 0.0219 - val_accuracy: 0.9965
# Epoch 16/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.0689 - accuracy: 0.9767 - val_loss: 0.0314 - val_accuracy: 0.9948
# Epoch 17/30
# 37/37 [==============================] - 1s 33ms/step - loss: 0.0715 - accuracy: 0.9762 - val_loss: 0.0651 - val_accuracy: 0.9723
# Epoch 18/30
# 37/37 [==============================] - 1s 34ms/step - loss: 0.0607 - accuracy: 0.9788 - val_loss: 0.0074 - val_accuracy: 0.9983
# Epoch 19/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.0618 - accuracy: 0.9797 - val_loss: 0.0571 - val_accuracy: 0.9792
# Epoch 20/30
# 37/37 [==============================] - 3s 61ms/step - loss: 0.0569 - accuracy: 0.9818 - val_loss: 0.1937 - val_accuracy: 0.9066
# Epoch 21/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.0872 - accuracy: 0.9723 - val_loss: 0.0328 - val_accuracy: 0.9931
# Epoch 22/30
# 37/37 [==============================] - 1s 31ms/step - loss: 0.0528 - accuracy: 0.9793 - val_loss: 0.2375 - val_accuracy: 0.8616
# Epoch 23/30
# 37/37 [==============================] - 1s 33ms/step - loss: 0.0533 - accuracy: 0.9831 - val_loss: 0.0115 - val_accuracy: 0.9965
# Epoch 24/30
# 37/37 [==============================] - 1s 33ms/step - loss: 0.0425 - accuracy: 0.9853 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 25/30
# 37/37 [==============================] - 1s 31ms/step - loss: 0.0478 - accuracy: 0.9853 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 26/30
# 37/37 [==============================] - 2s 38ms/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 0.0283 - val_accuracy: 0.9879
# Epoch 27/30
# 37/37 [==============================] - 2s 36ms/step - loss: 0.0359 - accuracy: 0.9896 - val_loss: 0.1720 - val_accuracy: 0.9204
# Epoch 28/30
# 37/37 [==============================] - 1s 34ms/step - loss: 0.0484 - accuracy: 0.9844 - val_loss: 0.1846 - val_accuracy: 0.9031
# Epoch 29/30
# 37/37 [==============================] - 1s 31ms/step - loss: 0.0548 - accuracy: 0.9797 - val_loss: 0.0202 - val_accuracy: 0.9913
# Epoch 30/30
# 37/37 [==============================] - 1s 32ms/step - loss: 0.0507 - accuracy: 0.9823 - val_loss: 0.0175 - val_accuracy: 0.9983

# %% [markdown]
# Visualizar resultados de entrenamiento:

# %%
# Grafica la precisión y pérdida de entrenamiento y validación
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Predecir en nuevas imagenes:

# %%
# Function to preprocess the image
def preprocess_image(image_path, target_size=(64, 64)):
    img = Image.open(image_path)
    img = img.resize(target_size)
    return img

# Test images directory
TEST_IMAGES_DIRECTORY = Path("rock-paper-scissors/test-dataset")

# Get list of test image paths
test_image_paths = list(TEST_IMAGES_DIRECTORY.glob("*.jpg"))

# Display 5 images with their actual and predicted classes
fig, axes = plt.subplots(1, 5, figsize=(15, 3))

for i, ax in enumerate(axes):
    # Preprocess the image
    image_path = test_image_paths[i]
    image = preprocess_image(image_path)
    ax.imshow(image)
    ax.axis('off')

    image = np.expand_dims(image, axis=0)  # Add batch dimension

    # Perform prediction
    prediction = model.predict(image)
    predicted_class_index = np.argmax(prediction)
    predicted_class = class_names[predicted_class_index]

    actual_class = ""
    if image_path.name.startswith("paper"):
        actual_class = "paper"
    elif image_path.name.startswith("rock"):
        actual_class = "rock"
    elif image_path.name.startswith("scissors"):
        actual_class = "scissors"

    # Display result
    ax.set_title(f"Actual: {actual_class}, Predicted: {predicted_class}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
